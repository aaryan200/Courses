# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a1 = np.loadtxt('iters1.dat')
plt.plot(a1[:,0], a1[:,2], label='Constant diffusivity')
a2 = np.loadtxt('iters2.dat')
plt.plot(a2[:,0], a2[:,2], label='Variable diffusivity')
plt.xlabel('nx')
plt.ylabel('Number of iterations')
plt.legend()
plt.grid()
plt.show()
