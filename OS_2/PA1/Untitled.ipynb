# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_thr, time = np.genfromtxt(r'out_const_numbers.txt', unpack=True)

# %%
num_thr
# Out:
# array([ 2.,  4.,  8., 16., 32.])

# %%
time
# Out:
# array([3062878., 2059238., 2680526., 3495718., 5362162.])

# %%
plt.plot(num_thr, time)
for i in range(5):
    plt.plot(num_thr[i],time[i],'ro-')
plt.xlabel("Number of Threads")
plt.ylabel("Time taken")
# plt.legend("Plot of Time taken vs Number of points")
plt.show()

# %%
1281081*2
# Out:
# 2562162
